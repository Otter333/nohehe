# %% [markdown]
# <a href="https://colab.research.google.com/github/Otter333/nohehe/blob/main/EX03_03_%E7%A9%BA%E6%B0%A3%E5%93%81%E8%B3%AA%E6%8C%87%E6%A8%99(AQI).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=9e565f9a-84dd-4e79-9097-d403cae1ea75&limit=1000&sort=ImportDate%20desc&format=CSV'
df = pd.read_csv(url)
df.head()
# Out:
#   sitename county  aqi pollutant status  so2    co  o3  o3_8hr  pm10  ...  \
# 0       基隆    基隆市   52     細懸浮微粒     普通  2.5  0.17  15      30    22  ...
# 1       汐止    新北市   65     細懸浮微粒     普通  0.6  0.28  17      39    28  ...
# 2       萬里    新北市   42       NaN     良好  NaN  0.15  30      35    22  ...
# 3       新店    新北市   61     細懸浮微粒     普通  1.2  0.35  20      45    31  ...
# 4       土城    新北市   68     細懸浮微粒     普通  1.4  0.37   7      37    31  ...
#
#    wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg pm10_avg  \
# 0         0.9         308  2025/04/22 21:00:00     0.2      13.0       22
# 1         2.4          51  2025/04/22 21:00:00     0.2      17.5       31
# 2         4.4          23  2025/04/22 21:00:00     0.1      10.4       23
# 3         1.3         146  2025/04/22 21:00:00     0.2      16.2       32
# 4         0.6         268  2025/04/22 21:00:00     0.2      18.7       33
#
#   so2_avg   longitude   latitude  siteid
# 0       1  121.760056  25.129167       1
# 1       0  121.640810  25.066240       2
# 2       0  121.689881  25.179667       3
# 3       1  121.537778  24.977222       4
# 4       0  121.451861  24.982528       5
#
# [5 rows x 24 columns]

# %%
df = df[['sitename', 'county', 'pollutant', 'status', 'aqi']]
df
# Out:
#        sitename county pollutant status  aqi
# 0            基隆    基隆市     細懸浮微粒     普通   52
# 1            汐止    新北市     細懸浮微粒     普通   65
# 2            萬里    新北市       NaN     良好   42
# 3            新店    新北市     細懸浮微粒     普通   61
# 4            土城    新北市     細懸浮微粒     普通   68
# ..          ...    ...       ...    ...  ...
# 81       屏東（琉球）    屏東縣      懸浮微粒     普通   58
# 82  台中市（和平區消防隊）    臺中市       NaN     良好   38
# 83       新北（樹林）    新北市       NaN     良好   47
# 84       臺南（南化）    臺南市       NaN     良好   40
# 85       屏東(枋山)    屏東縣       NaN     良好   50
#
# [86 rows x 5 columns]

# %%
condition=df['aqi']>100
df[condition]
# Out:
# Empty DataFrame
# Columns: [sitename, county, pollutant, status, aqi]
# Index: []

# %%
df['pollutant'].unique
df
# Out:
#        sitename county pollutant status  aqi
# 0            基隆    基隆市     細懸浮微粒     普通   52
# 1            汐止    新北市     細懸浮微粒     普通   65
# 2            萬里    新北市       NaN     良好   42
# 3            新店    新北市     細懸浮微粒     普通   61
# 4            土城    新北市     細懸浮微粒     普通   68
# ..          ...    ...       ...    ...  ...
# 81       屏東（琉球）    屏東縣      懸浮微粒     普通   58
# 82  台中市（和平區消防隊）    臺中市       NaN     良好   38
# 83       新北（樹林）    新北市       NaN     良好   47
# 84       臺南（南化）    臺南市       NaN     良好   40
# 85       屏東(枋山)    屏東縣       NaN     良好   50
#
# [86 rows x 5 columns]

# %%
condition=df['county']=='高雄市'
df[condition]
# Out:
#    sitename county pollutant status  aqi
# 46       美濃    高雄市       NaN     良好   40
# 47       橋頭    高雄市     細懸浮微粒     普通   52
# 48       仁武    高雄市       NaN     良好   46
# 49       鳳山    高雄市     細懸浮微粒     普通   62
# 50       大寮    高雄市     細懸浮微粒     普通   53
# 51       林園    高雄市     細懸浮微粒     普通   61
# 52       楠梓    高雄市     細懸浮微粒     普通   55
# 53       左營    高雄市     細懸浮微粒     普通   52
# 54       前金    高雄市       NaN     良好   41
# 55       前鎮    高雄市       NaN     良好   46
# 56       小港    高雄市     細懸浮微粒     普通   54
# 69       復興    高雄市       NaN     良好   50
# 80   高雄（湖內）    高雄市       NaN     良好   41

# %%
df.groupby('county')['aqi'].mean().sort_values(ascending=False)
# Out:
# county
# 連江縣    73.000000
# 金門縣    67.000000
# 新竹市    62.000000
# 新北市    59.769231
# 苗栗縣    59.666667
# 臺北市    59.000000
# 澎湖縣    59.000000
# 彰化縣    55.800000
# 臺中市    55.000000
# 桃園市    54.666667
# 嘉義縣    54.500000
# 新竹縣    54.000000
# 雲林縣    54.000000
# 宜蘭縣    53.666667
# 花蓮縣    53.000000
# 臺南市    52.000000
# 基隆市    52.000000
# 南投縣    51.666667
# 高雄市    50.230769
# 嘉義市    49.000000
# 屏東縣    48.800000
# 臺東縣    47.000000
# Name: aqi, dtype: float64
